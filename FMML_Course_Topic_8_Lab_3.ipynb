# %% [markdown]
# <a href="https://colab.research.google.com/github/9nani/FMML-projects-and-labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 09:48:03--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   111MB/s    in 0.6s
#
# 2024-03-26 09:48:04 (111 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 34718  1711.03373v2  Automatic Term Extraction deals with the extra...    cs
# 12116  1708.07807v1  Many of today's machine learning (ML) systems ...    cs
# 23078  1803.06030v2  Lactate threshold is considered an essential p...  stat
# 7424   1712.07454v1  A significantly faster algorithm is presented ...  stat
# 14259   1411.4086v1  Crowdsourcing has become an effective and popu...  stat
# ...             ...                                                ...   ...
# 26274  1609.06341v1  Problem of impulse noise reduction is a very w...    cs
# 1438   1712.05954v1  Cortical minicolumns are considered a model of...    cs
# 22025   1312.1970v1  We present an exploration of the rich theoreti...  stat
# 24963  1501.04276v1  This paper studies the subspace segmentation p...    cs
# 34699  1710.00372v1  Matrix syntax is a formal model of syntactic r...    cs
#
#                                                    title  year  \
# 34718  SemRe-Rank: Improving Automatic Term Extractio...  2017
# 12116  Modular Learning Component Attacks: Today's Re...  2017
# 23078  Estimation of lactate threshold with machine l...  2018
# 7424   Fast kNN mode seeking clustering applied to ac...  2017
# 14259  Error Rate Bounds and Iterative Weighted Major...  2014
# ...                                                  ...   ...
# 26274  Markov Random Field Model-Based Salt and Peppe...  2016
# 1438   An Artificial Neural Network Architecture Base...  2017
# 22025  An Algorithmic Theory of Dependent Regularizer...  2013
# 24963  Correlation Adaptive Subspace Segmentation by ...  2015
# 34699          Mathematical foundations of matrix syntax  2017
#
#                                                 keywords
# 34718  [automatic, extraction, extraction, terminolog...
# 12116  [compositions, components, increasing, signifi...
# 23078  [threshold, considered, essential, parameter, ...
# 7424   [significantly, algorithm, presented, procedur...
# 14259  [crowdsourcing, effective, computation, unreli...
# ...                                                  ...
# 26274  [reduction, processing, community, different, ...
# 1438   [minicolumns, considered, organization, reflec...
# 22025  [exploration, theoretical, connections, regula...
# 24963  [segmentation, subspaces, partition, underlyin...
# 34699  [syntactic, relations, mathematical, foundatio...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 34718    [automatic, extraction, extraction, terminolog...
# 12116    [compositions, components, increasing, signifi...
# 23078    [threshold, considered, essential, parameter, ...
# 7424     [significantly, algorithm, presented, procedur...
# 14259    [crowdsourcing, effective, computation, unreli...
#                                ...
# 22411    [algorithms, extremely, technique, expectation...
# 13999    [probabilistic, generative, applications, clas...
# 4459     [variation, regularization, foreground, backgr...
# 19726    [proceedings, conference, uncertainty, artific...
# 24112    [researchers, aesthetic, photographs, inspirat...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8726 words.
# Out of those 4571 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c3b5839e-8a7a-48e6-9c91-d1c2523f581c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3b5839e-8a7a-48e6-9c91-d1c2523f581c")) {                    Plotly.newPlot(                        "c3b5839e-8a7a-48e6-9c91-d1c2523f581c",                        [{"x":["improving","outperform","challenging","semantically","introduce","widespread","performance","incorporate","principle","embeddings","acquisition","potentially","personalised","extensively","terminology","evaluated","extraction","searching","importance","incorporates","percentage","overlooked","automatic","improvement","incorporating","established","consistently","knowledge","algorithm","perspective","candidate","relatedness","precision","alternative","justification","potential","characteristics","malfunction","dimensionality","countermeasures","simplifies","convexity","challenge","analytical","modifying","components","demonstrate","standardization","distortion","development","parameters","technical","challenges","healthcare","feasibility","adversary","compositions","linearity","fundamental","empirically","increasing","significantly","contributed","component","regulation","maintained","implications","predictable","assessment","objective","modification","therefore","prescribing","monitoring","resorting","calculate","specialized","equipment","accurately","inconvenient","recurrent","expensive","intensities","parameter","generalization","behaviour","evolution","traditional","correlation","assessing","estimates","participating","furthermore","essential","threshold","estimating","experimentally","aforementioned","estimation","intelligent","considered","stratified","measurement","techniques","concentration","complexity","computing","procedure","advantages","classification","dimensional","classifier","classifiers","resulting","presented","handwritten","assigning","clusterings","computational","clustering","structure","thousands","hierarchy","concluded","additional","computation","including","probability","simulated","theoretical","unreliable","effective","crowdsourcing","computationally","experimental","approximates","intuitive","aggregation","approximately","aggregate","exponential","guarantee","optimizes","posteriori","iterative","information","gradients","riemannian","allocation","stochastic","difficulties","demonstrated","constrained","marginalization","representation","dirichlet","exploiting","inference","different","augmentation","acceleration","bottleneck","complementary","positions","accelerate","convolutional","optimization","convolutions","additionally","strategies","technique","redundant","evaluation","deployment","elimination","extremely","intimately","mechanical","decreasing","particular","assumptions","associated","inferences","sequential","superiority","hierarchical","agglomerative","coalescent","algorithms","topological","designing","resolution","approximation","expressive","dimension","expression","considerations","invariance","architecture","parameterization"],"y":[105,92,256,27,334,16,860,70,62,78,45,40,3,41,7,147,126,38,100,29,13,7,171,145,57,45,24,348,820,60,53,10,90,94,13,178,97,3,53,4,10,13,141,24,13,107,561,6,17,118,237,41,124,7,24,12,5,6,86,82,108,283,5,104,3,5,27,5,44,163,23,143,1,42,4,18,20,5,58,1,131,53,8,113,121,26,61,188,76,20,75,10,168,58,31,77,47,12,228,59,141,3,46,413,20,232,140,116,90,523,184,146,136,153,195,29,18,4,282,163,318,31,41,5,113,149,223,169,69,153,8,284,14,81,361,7,32,30,39,23,37,32,9,9,78,721,34,11,35,139,27,89,59,4,367,20,73,201,738,31,16,20,40,26,19,365,314,14,63,105,272,18,261,19,13,40,0,8,10,271,70,128,6,87,43,114,7,0,621,15,43,101,107,32,61,47,12,21,239,10],"type":"bar"},{"x":["improving","outperform","challenging","semantical ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4571,), (4571, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8325

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4741379310344827);'>Automatic</span> <span style=''>Fado</span> <span style=''>Music</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <br/><br/><span style=''>In</span> <span style=''>late</span> <span style=''>2011</span> <span style=''>Fado</span> <span style=''>was</span> <span style=''>elevated</span> <span style=''>to</span> <span style=''>the</span> <span style=''>oral</span> <span style=''>and</span> <span style=''>intangible</span> <span style=''>heritage</span> <span style=''>of</span> <span style=''>humanity</span> <span style=''>by</span> <span style=''>UNESCO</span> <span style=''>This</span> <span style=''>study</span> <span style=''>aims</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4741379310344827);'>automatic</span> <span style='background-color:rgba(0, 255, 0, 0.5565410199556542);'>detection</span> <span style=''>of</span> <span style=''>Fado</span> <span style=''>music</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>audio</span> <span style=''>signal</span> <span style=''>To</span> <span style=''>do</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.44303797468354433);'>frequency</span> <span style=''>spectrum</span> <span style=''>related</span> <span style='background-color:rgba(0, 255, 0, 0.4264705882352941);'>characteristics</span> <span style=''>were</span> <span style=''>captured</span> <span style=''>form</span> <span style=''>the</span> <span style=''>audio</span> <span style=''>signal</span> <span style=''>in</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>the</span> <span style=''>Mel</span> <span style='background-color:rgba(0, 255, 0, 0.44303797468354433);'>Frequency</span> <span style=''>Cepstral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Coefficients</span> <span style=''>(MFCCs)</span> <span style=''>and</span> <span style=''>the</span> <span style=''>energy</span> <span style=''>of</span> <span style=''>the</span> <span style=''>signal</span> <span style=''>the</span> <span style=''>signal</span> <span style=''>was</span> <span style=''>further</span> <span style=''>analysed</span> <span style=''>in</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.44303797468354433);'>frequency</span> <span style=''>ranges</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>providing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style='background-color:rgba(0, 255, 0, 0.3121019108280255);'>information</span> <span style=''>Tests</span> <span style=''>were</span> <span style=''>run</span> <span style=''>both</span> <span style=''>in</span> <span style=''>a</span> <span style=''>10</span> <span style=''>fold</span> <span style=''>cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validation</span> <span style=''>setup</span> <span style=''>(976</span> <span style=''>accuracy)</span> <span style=''>and</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.34285714285714297);'>traditional</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>traintest</span> <span style=''>setup</span> <span style=''>(958</span> <span style=''>accuracy)</span> <span style=''>The</span> <span style=''>good</span> <span style=''>results</span> <span style=''>reflect</span> <span style=''>the</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>Fado</span> <span style=''>is</span> <span style=''>a</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>distinctive</span> <span style=''>musical</span> <span style=''>style</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Percolation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Thresholds</span> <span style=''>of</span> <span style=''>Updated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Posteriors</span> <span style=''>for</span> <span style=''>Tracking</span> <span style=''>Causal</span> <span style=''>Markov</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>in</span> <span style=''>Complex</span> <span style=''>Networks</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Percolation</span> <span style=''>on</span> <span style=''>complex</span> <span style=''>networks</span> <span style=''>has</span> <span style=''>been</span> <span style=''>used</span> <span style=''>to</span> <span style=''>study</span> <span style=''>computer</span> <span style=''>viruses</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>epidemics</span> <span style=''>and</span> <span style=''>other</span> <span style=''>casual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>present</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>network</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>phase</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>in</span> <span style=''>the</span> <span style=''>updated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>of</span> <span style=''>node</span> <span style=''>states</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>from</span> <span style=''>actively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>monitoring</span> <span style=''>the</span> <span style=''>network</span> <span style=''>Since</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>percolation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thresholds</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>Markov</span> <span style=''>chains</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>threshold</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>should</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accurately</span> <span style=''>model</span> <span style=''>the</span> <span style=''>true</span> <span style=''>phase</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>of</span> <span style=''>a</span> <span style=''>network</span> <span style=''>as</span> <span style=''>the</span> <span style=''>updated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accurately</span> <span style=''>tracks</span> <span style=''>the</span> <span style=''>process</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>should</span> <span style=''>provide</span> <span style=''>insight</span> <span style=''>into</span> <span style=''>modeling</span> <span style=''>the</span> <span style=''>dynamic</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Teaching</span> <span style='background-color:rgba(255, 0, 0, 0.3222222222222222);'>Dimension</span> <span style=''>of</span> <span style=''>Linear</span> <span style=''>Learners</span> <br/><br/><span style=''>Teaching</span> <span style='background-color:rgba(255, 0, 0, 0.3222222222222222);'>dimension</span> <span style=''>is</span> <span style=''>a</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretic</span> <span style=''>quantity</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>specifies</span> <span style=''>the</span> <span style=''>minimum</span> <span style=''>training</span> <span style=''>set</span> <span style=''>size</span> <span style=''>to</span> <span style=''>teach</span> <span style=''>a</span> <span style=''>target</span> <span style=''>model</span> <span style=''>to</span> <span style=''>a</span> <span style=''>learner</span> <span style=''>Previous</span> <span style=''>studies</span> <span style=''>on</span> <span style=''>teaching</span> <span style='background-color:rgba(255, 0, 0, 0.3222222222222222);'>dimension</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>version</span> <span style=''>space</span> <span style=''>learners</span> <span style=''>which</span> <span style=''>maintain</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypotheses</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>with</span> <span style=''>the</span> <span style=''>training</span> <span style=''>data</span> <span style=''>and</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>modern</span> <span style=''>machine</span> <span style=''>learners</span> <span style=''>which</span> <span style=''>select</span> <span style=''>a</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>the</span> <span style=''>first</span> <span style=''>known</span> <span style=''>teaching</span> <span style='background-color:rgba(255, 0, 0, 0.3222222222222222);'>dimension</span> <span style=''>for</span> <span style=''>ridge</span> <span style='background-color:rgba(255, 0, 0, 0.5029821073558647);'>regression</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machines</span> <span style=''>and</span> <span style=''>logistic</span> <span style='background-color:rgba(255, 0, 0, 0.5029821073558647);'>regression</span> <span style=''>We</span> <span style=''>also</span> <span style=''>exhibit</span> <span style=''>optimal</span> <span style=''>training</span> <span style=''>sets</span> <span style=''>that</span> <span style=''>match</span> <span style=''>these</span> <span style=''>teaching</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensions</span> <span style=''>Our</span> <span style=''>approach</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalizes</span> <span style=''>to</span> <span style=''>other</span> <span style=''>linear</span> <span style=''>learners</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Shape</span> <span style=''>Based</span> <span style=''>Approach</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Household</span> <span style=''>Load</span> <span style=''>Curve</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <br/><br/><span style=''>Consumer</span> <span style=''>Demand</span> <span style=''>Response</span> <span style=''>(DR)</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>research</span> <span style=''>and</span> <span style=''>industry</span> <span style=''>problem</span> <span style=''>which</span> <span style=''>seeks</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>categorize</span> <span style=''>predict</span> <span style=''>and</span> <span style=''>modify</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consumers</span> <span style=''>energy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consumption</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unfortunately</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>resulted</span> <span style=''>in</span> <span style=''>many</span> <span style=''>hundreds</span> <span style=''>of</span> <span style=''>clusters</span> <span style=''>with</span> <span style=''>a</span> <span style=''>given</span> <span style=''>consumer</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>several</span> <span style=''>clusters</span> <span style=''>making</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>classify</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consumers</span> <span style=''>into</span> <span style=''>stable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representative</span> <span style=''>groups</span> <span style=''>and</span> <span style=''>to</span> <span style=''>predict</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>energy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consumption</span> <span style=''>patterns</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>shape</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifies</span> <span style=''>and</span> <span style=''>predicts</span> <span style=''>consumer</span> <span style=''>energy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consumption</span> <span style=''>behavior</span> <span style=''>at</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>household</span> <span style=''>level</span> <span style=''>The</span> <span style=''>method</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Dynamic</span> <span style=''>Time</span> <span style=''>Warping</span> <span style=''>DTW</span> <span style=''>seeks</span> <span style=''>an</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alignment</span> <span style=''>between</span> <span style=''>energy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consumption</span> <span style=''>patterns</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reflecting</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06346360702760846)
# 	experimental (0.1294370742201506)
# 	architecture (0.08569379705987809)
# 	knowledge (0.12477590534241664)
# 	representation (0.1315883829329509)
# 	different (0.26461097167443526)
# 	information (0.2585155969881678)
# 	detection (0.12585155969881678)
# 	convolutional (0.13087128002868412)
# 	recognition (0.13840086052348513)
#
# Some Statistics words are:
# 	stochastic (0.13426156141223272)
# 	variables (0.13475882645450024)
# 	theoretical (0.14669318746892093)
# 	algorithm (0.38886126305320734)
# 	estimation (0.17851815017404277)
# 	statistical (0.1496767777225261)
# 	distribution (0.18100447538538042)
# 	dimensional (0.1844853306812531)
# 	inference (0.19890601690701143)
# 	regression (0.1879661859771258)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b5bba4e1-6bca-4e01-a1e5-26704bd2f52a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5bba4e1-6bca-4e01-a1e5-26704bd2f52a")) {                    Plotly.newPlot(                        "b5bba4e1-6bca-4e01-a1e5-26704bd2f52a",                        [{"x":["improving","outperform","challenging","semantically","introduce","widespread","performance","incorporate","principle","embeddings","acquisition","potentially","personalised","extensively","terminology","evaluated","extraction","searching","importance","incorporates","percentage","overlooked","automatic","improvement","incorporating","established","consistently","knowledge","algorithm","perspective","candidate","relatedness","precision","alternative","justification","potential","characteristics","malfunction","dimensionality","countermeasures","simplifies","convexity","challenge","analytical","modifying","components","demonstrate","standardization","distortion","development","parameters","technical","challenges","healthcare","feasibility","adversary","compositions","linearity","fundamental","empirically","increasing","significantly","contributed","component","regulation","maintained","implications","predictable","assessment","objective","modification","therefore","prescribing","monitoring","resorting","calculate","specialized","equipment","accurately","inconvenient","recurrent","expensive","intensities","parameter","generalization","behaviour","evolution","traditional","correlation","assessing","estimates","participating","furthermore","essential","threshold","estimating","experimentally","aforementioned","estimation","intelligent","considered","stratified","measurement","techniques","concentration","complexity","computing","procedure","advantages","classification","dimensional","classifier","classifiers","resulting","presented","handwritten","assigning","clusterings","computational","clustering","structure","thousands","hierarchy","concluded","additional","computation","including","probability","simulated","theoretical","unreliable","effective","crowdsourcing","computationally","experimental","approximates","intuitive","aggregation","approximately","aggregate","exponential","guarantee","optimizes","posteriori","iterative","information","gradients","riemannian","allocation","stochastic","difficulties","demonstrated","constrained","marginalization","representation","dirichlet","exploiting","inference","different","augmentation","acceleration","bottleneck","complementary","positions","accelerate","convolutional","optimization","convolutions","additionally","strategies","technique","redundant","evaluation","deployment","elimination","extremely","intimately","mechanical","decreasing","particular","assumptions","associated","inferences","sequential","superiority","hierarchical","agglomerative","coalescent","algorithms","topological","designing","resolution","approximation","expressive","dimension","expression","considerations","invariance","architecture","parameterization","universal","invariant","operators","framework","arbitrary","generalized","annotated","unavailable","parametric","objectness","annotations","supervised","initially","unlabeled","automatically","achieving","annotation","integrated","application","typically","detection","applications","projected","industrial","comparable","recognition","proposals","addresses","publication","architectures","prediction","predicted","addressed","formulated","traditionally","neuroscience","completely","minimization","euclidean","principles","orthogonal","regression","principal","satisfies","optimally","procrustes","coefficients","assumption","experiment","benchmarks","convergence","constraints","monotonic","nonparametric","com ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	intimately
# 	coalescent
# 	procrustes
# 	purchases
# 	covariances
# 	nonconvexity
# 	trivially
# 	triangulations
# 	assortativity
# 	neuroscientists
# 	commonplace
# 	interventional
# 	confounders
# 	marginalized
# 	correlational
# 	oscillates
# 	hemoglobin
# 	prospective
# 	rightarrow
# 	underestimates
# Some words which never appear in Statistics papers:
# 	terminology
# 	malfunction
# 	countermeasures
# 	objectness
# 	requested
# 	homography
# 	bilingual
# 	devnagari
# 	collocations
# 	lexicography
# 	simplifications
# 	utterances
# 	prisoners
# 	designers
# 	accomplishing
# 	conversations
# 	conversation
# 	guesswhat
# 	individuating
# 	delineating

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0806198207079265e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7908333333333334
